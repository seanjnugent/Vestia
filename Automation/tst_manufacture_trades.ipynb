# %%
import random
import psycopg2
from datetime import datetime, timedelta
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Database connection setup
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_name = os.getenv("DB_NAME")

# Establish the connection using psycopg2
conn = psycopg2.connect(
    dbname=db_name, user=db_user, password=db_password, host=db_host
)
print(f"Connected to database: {db_name}")

def get_cash_balance(conn, account_id):
    with conn.cursor() as cur:
        cur.execute("""
            SELECT total_cash_balance
            FROM public.vw_cash_balance
            WHERE accountid = %s
            ORDER BY total_cash_balance DESC
            LIMIT 1;
        """, (account_id,))
        result = cur.fetchone()
    return result[0] if result else 0

def get_asset_list(conn):
    with conn.cursor() as cur:
        cur.execute("""
            SELECT assetid, latestprice, currencycode
            FROM public.vw_latest_price
            WHERE assetid != 699;
        """)
        return cur.fetchall()

def simulate_trade(conn, account_id):
    try:
        # Get the cash balance for the account
        cash_balance = get_cash_balance(conn, account_id)

        # Only process if the cash balance is greater than 0
        if cash_balance <= 0:
            print(f"Account {account_id} has insufficient cash balance (cash balance: {cash_balance}). Skipping.")
            return

        # Retrieve the asset list (assets available for trade)
        assets = get_asset_list(conn)

        if not assets:
            print(f"No assets available for trading for account {account_id}.")
            return

        # Select a random asset to trade
        asset_id, asset_price, currency_code = random.choice(assets)

        # Explicitly convert to standard Python types (float for account_id and asset_id)
        account_id = float(account_id)
        asset_id = int(asset_id)

        # Debug print the cash balance and asset price
        print(f"Account {account_id} has cash balance: {cash_balance}, selected asset {asset_id} price: {asset_price}")

        # Determine the maximum quantity the user can afford to buy based on the cash balance
        max_quantity = cash_balance // asset_price

        # Debug print the max quantity
        print(f"Account {account_id} can afford {max_quantity} units of asset {asset_id}.")

        if max_quantity < 1:
            print(f"Account {account_id} does not have enough balance to buy any asset.")
            return

        # Randomly choose trade type: Buy or Sell
        trade_type = random.choice(['Buy', 'Sell'])

        # Buy Logic
        if trade_type == 'Buy':
            trade_quantity = random.randint(1, max_quantity)
            trade_cost = trade_quantity * asset_price

            # Check if account has enough cash to complete the buy trade
            if trade_cost > cash_balance:
                print(f"Account {account_id} does not have enough cash for the buy trade.")
                return

            # Insert buy trade into the trade table
            with conn.cursor() as cur:
                cur.execute("""
                    INSERT INTO public.trade (
                        accountid, assetid, tradequantity, tradecost, tradetype, tradestatus, datecreated, dateupdated
                    )
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                """, (account_id, asset_id, trade_quantity, trade_cost, 'Buy', 'Completed', datetime.now(), datetime.now()))

            # Deduct the cost of the buy trade from the cash balance by inserting a "buy" for asset ID 699
            with conn.cursor() as cur:
                cur.execute("""
                    INSERT INTO public.trade (
                        accountid, assetid, tradequantity, tradecost, tradetype, tradestatus, datecreated, dateupdated
                    )
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                """, (account_id, 699, trade_quantity, -trade_cost, 'Buy', 'Completed', datetime.now(), datetime.now()))

            conn.commit()

            print(f"Account {account_id} bought {trade_quantity} of asset {asset_id} at {asset_price} {currency_code}. Deducted {trade_cost} from cash.")

        # Sell Logic
        elif trade_type == 'Sell':
            # First, check how much of the asset the account owns
            with conn.cursor() as cur:
                cur.execute("""
                    SELECT SUM(tradequantity) as total_quantity
                    FROM public.trade
                    WHERE accountid = %s AND assetid = %s AND tradetype = 'Buy' AND datecreated < %s;
                """, (account_id, asset_id, datetime.now().date()))
                result = cur.fetchone()

            owned_quantity = result[0] or 0

            # Ensure the account has enough of the asset to sell
            if owned_quantity <= 0:
                print(f"Account {account_id} does not own any {asset_id} to sell.")
                return

            trade_quantity = random.randint(1, min(owned_quantity, max_quantity))  # Sell a random quantity, up to the maximum allowed
            trade_cost = trade_quantity * asset_price  # Proceeds from selling

            # Insert sell trade into the trade table
            with conn.cursor() as cur:
                cur.execute("""
                    INSERT INTO public.trade (
                        accountid, assetid, tradequantity, tradecost, tradetype, tradestatus, datecreated, dateupdated
                    )
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                """, (account_id, asset_id, trade_quantity, trade_cost, 'Sell', 'Completed', datetime.now(), datetime.now()))

            # Add the proceeds from the sale to the cash balance by inserting a "sell" for asset ID 699
            with conn.cursor() as cur:
                cur.execute("""
                    INSERT INTO public.trade (
                        accountid, assetid, tradequantity, tradecost, tradetype, tradestatus, datecreated, dateupdated
                    )
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                """, (account_id, 699, trade_quantity, trade_cost, 'Sell', 'Completed', datetime.now(), datetime.now()))

            conn.commit()

            print(f"Account {account_id} sold {trade_quantity} of asset {asset_id} at {asset_price} {currency_code}. Added {trade_cost} to cash.")

    except Exception as e:
        print(f"Error simulating trade for account {account_id}: {e}")

# Example usage: Simulate trades for 1000 random accounts
for _ in range(10000):
    simulate_trade(conn, random.randint(80000, 200000))

conn.close()
# Out:
# Connected to database: postgres
# Account 173143.0 has cash balance: 3000, selected asset 690 price: 106.37000
# Account 173143.0 can afford 28 units of asset 690.
# Account 173143.0 does not own any 690 to sell.
# Account 162683.0 has cash balance: 3000, selected asset 670 price: 107.53000
# Account 162683.0 can afford 27 units of asset 670.
# Account 162683.0 does not own any 670 to sell.
# Account 123084.0 has cash balance: 2000, selected asset 623 price: 17.82000
# Account 123084.0 can afford 112 units of asset 623.
# Account 123084.0 does not own any 623 to sell.
# Account 116994.0 has cash balance: 1000, selected asset 691 price: 177.96271
# Account 116994.0 can afford 5 units of asset 691.
# Account 116994.0 does not own any 691 to sell.
# Account 132825.0 has cash balance: 1000, selected asset 604 price: 423.41501
# Account 132825.0 can afford 2 units of asset 604.
# Account 132825.0 bought 2 of asset 604 at 423.41501 USD. Deducted 846.83002 from cash.
# Account 96010.0 has cash balance: 3000, selected asset 677 price: 63.99000
# Account 96010.0 can afford 46 units of asset 677.
# Account 96010.0 does not own any 677 to sell.
# Account 128152 has insufficient cash balance (cash balance: 0). Skipping.
# Account 129807.0 has cash balance: 1000, selected asset 660 price: 238.57001
# Account 129807.0 can afford 4 units of asset 660.
# Account 129807.0 does not own any 660 to sell.
# Account 161953.0 has cash balance: 3000, selected asset 609 price: 149.47000
# Account 161953.0 can afford 20 units of asset 609.
# Account 161953.0 does not own any 609 to sell.
# Account 187099 has insufficient cash balance (cash balance: 0). Skipping.
# Account 136127 has insufficient cash balance (cash balance: 0). Skipping.
# Account 173663.0 has cash balance: 5000, selected asset 655 price: 694204.75000
# Account 173663.0 can afford 0 units of asset 655.
# Account 173663.0 does not have enough balance to buy any asset.
# Account 148344.0 has cash balance: 3000, selected asset 603 price: 226.70500
# Account 148344.0 can afford 13 units of asset 603.
# Account 148344.0 does not own any 603 to sell.
# Account 146107.0 has cash balance: 1000, selected asset 655 price: 694204.75000
# Account 146107.0 can afford 0 units of asset 655.
# Account 146107.0 does not have enough balance to buy any asset.
# Account 146290 has insufficient cash balance (cash balance: 0). Skipping.
# Account 182735 has insufficient cash balance (cash balance: 0). Skipping.
# Account 153928.0 has cash balance: 2000, selected asset 608 price: 315.12991
# Account 153928.0 can afford 6 units of asset 608.
# Account 153928.0 does not own any 608 to sell.
# Account 148792.0 has cash balance: 4000, selected asset 590 price: 38.50500
# Account 148792.0 can afford 103 units of asset 590.
# Account 148792.0 does not own any 590 to sell.
# Account 181687 has insufficient cash balance (cash balance: 0). Skipping.
# Account 95545 has insufficient cash balance (cash balance: 0). Skipping.
# Account 88332.0 has cash balance: 3000, selected asset 637 price: 6.42500
# Account 88332.0 can afford 466 units of asset 637.
# Account 88332.0 does not own any 637 to sell.
# Account 186873 has insufficient cash balance (cash balance: 0). Skipping.
# Account 144712 has insufficient cash balance (cash balance: 0). Skipping.
# Account 179837.0 has cash balance: 2000, selected asset 690 price: 106.37000
# Account 179837.0 can afford 18 units of asset 690.
# Account 179837.0 does not own any 690 to sell.
# Account 175320.0 has cash balance: 5000, selected asset 612 price: 204.71500
# Account 175320.0 can afford 24 units of asset 612.
# Account 175320.0 bought 18 of asset 612 at 204.71500 USD. Deducted 3684.87000 from cash.
# Account 97421.0 has cash balance: 3000, selected asset 608 price: 315.12991
# Account 97421.0 can afford 9 units of asset 608.
# Account 97421.0 does not own any 608 to sell.
# Account 159947.0 has cash balance: 5000, selected asset 682 price: 359.47000
# Account 159947.0 can afford 13 units of asset 682.
# Account 159947.0 bought 2 of asset 682 at 359.47000 USD. Deducted 718.94000 from cash.
# Account 146611.0 has cash balance: 1000, selected asset 654 price: 201.88000
# Account 146611.0 can afford 4 units of asset 654.
# Account 146611.0 bought 2 of asset 654 at 201.88000 USD. Deducted 403.76000 from cash.
# Account 184784 has insufficient cash balance (cash balance: 0). Skipping.
# Account 173940.0 has cash balance: 1000, selected asset 645 price: 36.72000
# Account 173940.0 can afford 27 units of asset 645.
# Account 173940.0 bought 21 of asset 645 at 36.72000 USD. Deducted 771.12000 from cash.
# Account 146645.0 has cash balance: 1000, selected asset 659 price: 85.21010
# Account 146645.0 can afford 11 units of asset 659.
# Account 146645.0 does not own any 659 to sell.
# Account 179954.0 has cash balance: 2000, selected asset 589 price: 94.10500
# Account 179954.0 can afford 21 units of asset 589.
# Account 179954.0 does not own any 589 to sell.
# Account 126306.0 has cash balance: 4000, selected asset 670 price: 107.53000
# Account 126306.0 can afford 37 units of asset 670.
# Account 126306.0 bought 10 of asset 670 at 107.53000 USD. Deducted 1075.30000 from cash.
# Account 99124.0 has cash balance: 2000, selected asset 637 price: 6.42500
# Account 99124.0 can afford 311 units of asset 637.
# Account 99124.0 does not own any 637 to sell.
# Account 163203.0 has cash balance: 2000, selected asset 598 price: 22.90500
# Account 163203.0 can afford 87 units of asset 598.
# Account 163203.0 does not own any 598 to sell.
# Account 128484.0 has cash balance: 2000, selected asset 682 price: 359.47000
# Account 128484.0 can afford 5 units of asset 682.
# Account 128484.0 bought 3 of asset 682 at 359.47000 USD. Deducted 1078.41000 from cash.
# Account 156271.0 has cash balance: 4000, selected asset 590 price: 38.50500
# Account 156271.0 can afford 103 units of asset 590.
# Account 156271.0 bought 13 of asset 590 at 38.50500 USD. Deducted 500.56500 from cash.
# Account 104544.0 has cash balance: 4000, selected asset 612 price: 204.71500
# Account 104544.0 can afford 19 units of asset 612.
# Account 104544.0 does not own any 612 to sell.
# Account 99932.0 has cash balance: 3000, selected asset 607 price: 586.73993
# Account 99932.0 can afford 5 units of asset 607.
# Account 99932.0 bought 2 of asset 607 at 586.73993 USD. Deducted 1173.47986 from cash.
# Account 92341 has insufficient cash balance (cash balance: 0). Skipping.
# Account 187341 has insufficient cash balance (cash balance: 0). Skipping.
# Account 81283 has insufficient cash balance (cash balance: 0). Skipping.
# Account 85961.0 has cash balance: 1000, selected asset 613 price: 72.05000
# Account 85961.0 can afford 13 units of asset 613.
# Account 85961.0 bought 6 of asset 613 at 72.05000 USD. Deducted 432.30000 from cash.
# Account 186613 has insufficient cash balance (cash balance: 0). Skipping.
# Account 149808.0 has cash balance: 3000, selected asset 674 price: 316.48999
# Account 149808.0 can afford 9 units of asset 674.
# Account 149808.0 bought 7 of asset 674 at 316.48999 USD. Deducted 2215.42993 from cash.
# Account 148152.0 has cash balance: 2000, selected asset 607 price: 586.73993
# Account 148152.0 can afford 3 units of asset 607.
# Account 148152.0 does not own any 607 to sell.
# Account 174476.0 has cash balance: 2000, selected asset 688 price: 462.20999
# Account 174476.0 can afford 4 units of asset 688.
# Account 174476.0 does not own any 688 to sell.
# Account 86984.0 has cash balance: 5000, selected asset 690 price: 106.37000
# Account 86984.0 can afford 47 units of asset 690.
# Account 86984.0 does not own any 690 to sell.
# Account 133868.0 has cash balance: 5000, selected asset 608 price: 315.12991
# Account 133868.0 can afford 15 units of asset 608.
# Account 133868.0 does not own any 608 to sell.
# Account 113852.0 has cash balance: 4000, selected asset 693 price: 299.67010
# Account 113852.0 can afford 13 units of asset 693.
# Account 113852.0 does not own any 693 to sell.
# Account 187140 has insufficient cash balance (cash balance: 0). Skipping.
# Account 146155 has insufficient cash balance (cash balance: 0). Skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 163
#     161 # Example usage: Simulate trades for 1000 random accounts
#     162 for _ in range(10000):
# --> 163     simulate_trade(conn, random.randint(80000, 200000))
#     165 conn.close()
#
# Cell In[4], line 46, in simulate_trade(conn, account_id)
#      43 def simulate_trade(conn, account_id):
#      44     try:
#      45         # Get the cash balance for the account
# ---> 46         cash_balance = get_cash_balance(conn, account_id)
#      48         # Only process if the cash balance is greater than 0
#      49         if cash_balance <= 0:
#
# Cell In[4], line 24, in get_cash_balance(conn, account_id)
#      22 def get_cash_balance(conn, account_id):
#      23     with conn.cursor() as cur:
# ---> 24         cur.execute("""
#      25             SELECT total_cash_balance
#      26             FROM public.vw_cash_balance
#      27             WHERE accountid = %s
#      28             ORDER BY total_cash_balance DESC
#      29             LIMIT 1;
#      30         """, (account_id,))
#      31         result = cur.fetchone()
#      32     return result[0] if result else 0
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\encodings\utf_8.py:15, in decode(input, errors)
#      11 ### Codec APIs
#      13 encode = codecs.utf_8_encode
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# KeyboardInterrupt:
